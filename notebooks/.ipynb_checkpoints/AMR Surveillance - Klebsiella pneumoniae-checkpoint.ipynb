# %% [markdown]
# ### Import modules and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)
# %matplotlib inline

# %%
df = pd.read_csv('OpenAtlas_Reuse_Data.csv', sep='\t')
# Out:
# /home/sc/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5,19,20,23,24,29,30,35,36,43,44,55,56,57,58,59,62,63,64,65,67,68,69,70,71,72,73,75,76,77,78,79,80,81,83,84,85,86,87,88,89,90,91,93,94,95,96,97,98,99,100) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Choose species

# %%
species = df['Species']=='Klebsiella pneumoniae'

# %%
df_kleb = df[species].copy()

# %% [markdown]
# ### Inspect Klebsiella dataframe

# %%
df_kleb.shape
# Out:
# (64296, 101)

# %% [markdown]
# ### Check for missing "Resistant", "Susceptible" or "Intermediate" assignments in "_I" column

# %%
for col in df_kleb.columns:
    if col.endswith('_I'):
        col2 = col[:-2]
        if df_kleb[[col2, col]].isnull().any().any():
            result = df_kleb.fillna('(missing)').groupby([col2, col]).size().to_frame().reset_index()
            cond = (result[col]=='(missing)') & (result[col2]!='(missing)')
            cond |= (result[col2]=='(missing)') & (result[col]!='(missing)')
            if result[cond].shape[0] != 0:
                print('ARGHHH', col, col2)
                print(result[cond])
                print(result)
# Out:
# ARGHHH Aztreonam avibactam_I Aztreonam avibactam
#    Aztreonam avibactam Aztreonam avibactam_I     0
# 1                 0.03             (missing)  6459
# 2                 0.06             (missing)  7346
# 3                 0.12             (missing)  4120
# 4                 0.25             (missing)  1694
# 5                  0.5             (missing)   554
# 6                    1             (missing)   141
# 7                   16             (missing)     4
# 8                    2             (missing)   102
# 9                   32             (missing)     4
# 10                   4             (missing)    20
# 11                  64             (missing)     3
# 12                   8             (missing)     2
# 13             <=0.015             (missing)  2316
#    Aztreonam avibactam Aztreonam avibactam_I      0
# 0            (missing)             (missing)  41531
# 1                 0.03             (missing)   6459
# 2                 0.06             (missing)   7346
# 3                 0.12             (missing)   4120
# 4                 0.25             (missing)   1694
# 5                  0.5             (missing)    554
# 6                    1             (missing)    141
# 7                   16             (missing)      4
# 8                    2             (missing)    102
# 9                   32             (missing)      4
# 10                   4             (missing)     20
# 11                  64             (missing)      3
# 12                   8             (missing)      2
# 13             <=0.015             (missing)   2316
# ARGHHH Ceftaroline avibactam_I Ceftaroline avibactam
#    Ceftaroline avibactam Ceftaroline avibactam_I     0
# 1                  0.015               (missing)   226
# 2                   0.03               (missing)  1487
# 3                   0.06               (missing)  4144
# 4                   0.12               (missing)  2247
# 5                   0.25               (missing)   953
# 6                    0.5               (missing)   467
# 7                      1               (missing)   200
# 8                    128               (missing)    10
# 9                     16               (missing)     9
# 10                     2               (missing)   115
# 11                    32               (missing)    16
# 12                     4               (missing)    63
# 13                    64               (missing)     8
# 14                     8               (missing)    27
# 15               <=0.008               (missing)   141
# 16                  >128               (missing)    42
#    Ceftaroline avibactam Ceftaroline avibactam_I      0
# 0              (missing)               (missing)  54141
# 1                  0.015               (missing)    226
# 2                   0.03               (missing)   1487
# 3                   0.06               (missing)   4144
# 4                   0.12               (missing)   2247
# 5                   0.25               (missing)    953
# 6                    0.5               (missing)    467
# 7                      1               (missing)    200
# 8                    128               (missing)     10
# 9                     16               (missing)      9
# 10                     2               (missing)    115
# 11                    32               (missing)     16
# 12                     4               (missing)     63
# 13                    64               (missing)      8
# 14                     8               (missing)     27
# 15               <=0.008               (missing)    141
# 16                  >128               (missing)     42
# ARGHHH Colistin_I Colistin
#    Colistin Colistin_I     0
# 1      0.12  (missing)   262
# 2      0.25  (missing)  6560
# 3       0.5  (missing)  5009
# 4         1  (missing)  4601
# 5         2  (missing)   375
# 6         4  (missing)    89
# 7         8  (missing)    88
# 8    <=0.06  (missing)     7
# 9    <=0.12  (missing)     4
# 10       >4  (missing)   151
# 11       >8  (missing)   364
#      Colistin Colistin_I      0
# 0   (missing)  (missing)  46786
# 1        0.12  (missing)    262
# 2        0.25  (missing)   6560
# 3         0.5  (missing)   5009
# 4           1  (missing)   4601
# 5           2  (missing)    375
# 6           4  (missing)     89
# 7           8  (missing)     88
# 8      <=0.06  (missing)      7
# 9      <=0.12  (missing)      4
# 10         >4  (missing)    151
# 11         >8  (missing)    364
# ARGHHH ColistinP80_I ColistinP80
#    ColistinP80 ColistinP80_I     0
# 1         0.03     (missing)  1826
# 2         0.06     (missing)  1953
# 3         0.12     (missing)   425
# 4         0.25     (missing)   588
# 5          0.5     (missing)   103
# 6            1     (missing)    51
# 7            2     (missing)    42
# 8            4     (missing)    21
# 9      <=0.015     (missing)   184
# 10      <=0.12     (missing)  4711
# 11          >4     (missing)   251
#    ColistinP80 ColistinP80_I      0
# 0    (missing)     (missing)  54141
# 1         0.03     (missing)   1826
# 2         0.06     (missing)   1953
# 3         0.12     (missing)    425
# 4         0.25     (missing)    588
# 5          0.5     (missing)    103
# 6            1     (missing)     51
# 7            2     (missing)     42
# 8            4     (missing)     21
# 9      <=0.015     (missing)    184
# 10      <=0.12     (missing)   4711
# 11          >4     (missing)    251

# %% [markdown]
# ### Define Breakpoints for Missing Klebsiella Antibiotics (Enterobacterales)

# %%
# Breakpoints for Klebsiella pneumoniae
# Aztreonam avibactum: Sensitive: <= 4, Resistant: > 4 
# Ceftazidime-avibactam: Sensitive: <= 8, Resistant: > 8
# Colistin: Sensitive: <= 2, Resistant: > 2 
# ColistinP80: Sensitive: <= 2, Resistant: > 2

# %%
col1, col2 = 'Aztreonam avibactam', 'Aztreonam avibactam_I'
df_kleb.loc[~df_kleb[col1].isnull(), col2] = 'Susceptible'
df_kleb.loc[df_kleb[col1].isin(['16','32','64','8']), col2] = 'Resistant'

# %%
df_kleb.fillna('(missing)').groupby([col1, col2]).size()
# Out:
# Aztreonam avibactam  Aztreonam avibactam_I
# (missing)            (missing)                41531
# 0.03                 Susceptible               6459
# 0.06                 Susceptible               7346
# 0.12                 Susceptible               4120
# 0.25                 Susceptible               1694
# 0.5                  Susceptible                554
# 1                    Susceptible                141
# 16                   Resistant                    4
# 2                    Susceptible                102
# 32                   Resistant                    4
# 4                    Susceptible                 20
# 64                   Resistant                    3
# 8                    Resistant                    2
# <=0.015              Susceptible               2316
# dtype: int64

# %%
col1 = 'Ceftaroline avibactam'
col2 = col1 + '_I'
df_kleb.loc[~df_kleb[col1].isnull(), col2] = 'Susceptible'
df_kleb.loc[df_kleb[col1].isin(['16','32','64','128', '>128']), col2] = 'Resistant'

# %%
df_kleb.fillna('(missing)').groupby([col1, col2]).size()
# Out:
# Ceftaroline avibactam  Ceftaroline avibactam_I
# (missing)              (missing)                  54141
# 0.015                  Susceptible                  226
# 0.03                   Susceptible                 1487
# 0.06                   Susceptible                 4144
# 0.12                   Susceptible                 2247
# 0.25                   Susceptible                  953
# 0.5                    Susceptible                  467
# 1                      Susceptible                  200
# 128                    Resistant                     10
# 16                     Resistant                      9
# 2                      Susceptible                  115
# 32                     Resistant                     16
# 4                      Susceptible                   63
# 64                     Resistant                      8
# 8                      Susceptible                   27
# <=0.008                Susceptible                  141
# >128                   Resistant                     42
# dtype: int64

# %%
col1 = 'Colistin'
col2 = col1 + '_I'
df_kleb.loc[~df_kleb[col1].isnull(), col2] = 'Susceptible'
df_kleb.loc[df_kleb[col1].isin(['4', '8', '>4', '>8']), col2] = 'Resistant'

# %%
df_kleb.fillna('(missing)').groupby([col1, col2]).size()
# Out:
# Colistin   Colistin_I
# (missing)  (missing)      46786
# 0.12       Susceptible      262
# 0.25       Susceptible     6560
# 0.5        Susceptible     5009
# 1          Susceptible     4601
# 2          Susceptible      375
# 4          Resistant         89
# 8          Resistant         88
# <=0.06     Susceptible        7
# <=0.12     Susceptible        4
# >4         Resistant        151
# >8         Resistant        364
# dtype: int64

# %%
col1 = 'ColistinP80'
col2 = col1 + '_I'
df_kleb.loc[~df_kleb[col1].isnull(), col2] = 'Susceptible'
df_kleb.loc[df_kleb[col1].isin(['4', '>4']), col2] = 'Resistant'

# %%
df_kleb.fillna('(missing)').groupby([col1, col2]).size()
# Out:
# ColistinP80  ColistinP80_I
# (missing)    (missing)        54141
# 0.03         Susceptible       1826
# 0.06         Susceptible       1953
# 0.12         Susceptible        425
# 0.25         Susceptible        588
# 0.5          Susceptible        103
# 1            Susceptible         51
# 2            Susceptible         42
# 4            Resistant           21
# <=0.015      Susceptible        184
# <=0.12       Susceptible       4711
# >4           Resistant          251
# dtype: int64

# %% [markdown]
# ### Clean the dataframe - keep country, year and antibiotic r/s/i assignments

# %%
cols_keep_a = ['Country', 'Year']

# %%
cols_keep_b = [x for x in df_kleb.columns if x.endswith('_I')]

# %%
df_kleb_clean = df_kleb[cols_keep_a + cols_keep_b].copy()

# %%
df_kleb_clean.head()
# Out:
#    Country  Year   Amikacin_I Amoxycillin clavulanate_I  Ampicillin_I  \
# 30  France  2013  Susceptible               Susceptible  Intermediate
# 36  France  2013  Susceptible               Susceptible     Resistant
# 52  France  2013  Susceptible               Susceptible     Resistant
# 53  France  2013  Susceptible               Susceptible     Resistant
# 54  France  2013  Susceptible               Susceptible     Resistant
#
#    Azithromycin_I   Cefepime_I Cefoxitin_I Ceftazidime_I Ceftriaxone_I  \
# 30            NaN  Susceptible         NaN   Susceptible   Susceptible
# 36            NaN  Susceptible         NaN   Susceptible   Susceptible
# 52            NaN  Susceptible         NaN   Susceptible   Susceptible
# 53            NaN  Susceptible         NaN   Susceptible   Susceptible
# 54            NaN  Susceptible         NaN   Susceptible   Susceptible
#
#    Clarithromycin_I Clindamycin_I Erythromycin_I Imipenem_I Levofloxacin_I  \
# 30              NaN           NaN            NaN        NaN    Susceptible
# 36              NaN           NaN            NaN        NaN    Susceptible
# 52              NaN           NaN            NaN        NaN    Susceptible
# 53              NaN           NaN            NaN        NaN    Susceptible
# 54              NaN           NaN            NaN        NaN    Susceptible
#
#    Linezolid_I  Meropenem_I Metronidazole_I Minocycline_I Penicillin_I  \
# 30         NaN  Susceptible             NaN   Susceptible          NaN
# 36         NaN  Susceptible             NaN   Susceptible          NaN
# 52         NaN  Susceptible             NaN   Susceptible          NaN
# 53         NaN  Susceptible             NaN   Susceptible          NaN
# 54         NaN  Susceptible             NaN   Susceptible          NaN
#
#    Piperacillin tazobactam_I Tigecycline_I Vancomycin_I  \
# 30               Susceptible   Susceptible          NaN
# 36               Susceptible   Susceptible          NaN
# 52               Susceptible   Susceptible          NaN
# 53               Susceptible   Susceptible          NaN
# 54               Susceptible   Susceptible          NaN
#
#    Ampicillin sulbactam_I Aztreonam_I Aztreonam avibactam_I Cefixime_I  \
# 30                    NaN         NaN                   NaN        NaN
# 36                    NaN         NaN                   NaN        NaN
# 52                    NaN         NaN                   NaN        NaN
# 53                    NaN         NaN                   NaN        NaN
# 54                    NaN         NaN                   NaN        NaN
#
#    Ceftaroline_I Ceftaroline avibactam_I Ceftazidime avibactam_I  \
# 30           NaN                     NaN                     NaN
# 36           NaN                     NaN                     NaN
# 52           NaN                     NaN                     NaN
# 53           NaN                     NaN                     NaN
# 54           NaN                     NaN                     NaN
#
#    Ciprofloxacin_I Colistin_I ColistinP80_I Daptomycin_I Doripenem_I  \
# 30             NaN        NaN           NaN          NaN         NaN
# 36             NaN        NaN           NaN          NaN         NaN
# 52             NaN        NaN           NaN          NaN         NaN
# 53             NaN        NaN           NaN          NaN         NaN
# 54             NaN        NaN           NaN          NaN         NaN
#
#    Ertapenem_I  Gatifloxacin_I Gentamicin_I Moxifloxacin_I Oxacillin_I  \
# 30         NaN             NaN          NaN            NaN         NaN
# 36         NaN             NaN          NaN            NaN         NaN
# 52         NaN             NaN          NaN            NaN         NaN
# 53         NaN             NaN          NaN            NaN         NaN
# 54         NaN             NaN          NaN            NaN         NaN
#
#    Quinupristin dalfopristin_I  Sulbactam_I Teicoplanin_I Tetracycline_I  \
# 30                         NaN          NaN           NaN            NaN
# 36                         NaN          NaN           NaN            NaN
# 52                         NaN          NaN           NaN            NaN
# 53                         NaN          NaN           NaN            NaN
# 54                         NaN          NaN           NaN            NaN
#
#    Trimethoprim sulfa_I Ceftolozane tazobactam_I
# 30                  NaN                      NaN
# 36                  NaN                      NaN
# 52                  NaN                      NaN
# 53                  NaN                      NaN
# 54                  NaN                      NaN

# %% [markdown]
# ### Check for columns with no values at all

# %%
df_kleb_clean.isnull().all()
# Out:
# Country                        False
# Year                           False
# Amikacin_I                     False
# Amoxycillin clavulanate_I      False
# Ampicillin_I                   False
# Azithromycin_I                  True
# Cefepime_I                     False
# Cefoxitin_I                     True
# Ceftazidime_I                  False
# Ceftriaxone_I                  False
# Clarithromycin_I                True
# Clindamycin_I                   True
# Erythromycin_I                  True
# Imipenem_I                     False
# Levofloxacin_I                 False
# Linezolid_I                     True
# Meropenem_I                    False
# Metronidazole_I                 True
# Minocycline_I                  False
# Penicillin_I                    True
# Piperacillin tazobactam_I      False
# Tigecycline_I                  False
# Vancomycin_I                    True
# Ampicillin sulbactam_I          True
# Aztreonam_I                    False
# Aztreonam avibactam_I          False
# Cefixime_I                      True
# Ceftaroline_I                  False
# Ceftaroline avibactam_I        False
# Ceftazidime avibactam_I        False
# Ciprofloxacin_I                 True
# Colistin_I                     False
# ColistinP80_I                  False
# Daptomycin_I                    True
# Doripenem_I                    False
# Ertapenem_I                    False
# Gatifloxacin_I                  True
# Gentamicin_I                    True
# Moxifloxacin_I                  True
# Oxacillin_I                     True
# Quinupristin dalfopristin_I     True
# Sulbactam_I                     True
# Teicoplanin_I                   True
# Tetracycline_I                  True
# Trimethoprim sulfa_I            True
# Ceftolozane tazobactam_I       False
# dtype: bool

# %% [markdown]
# ### Remove those columns and inspect

# %%
df_kleb_clean.dropna(axis=1, how='all', inplace=True)

# %%
df_kleb_clean.isnull().all()
# Out:
# Country                      False
# Year                         False
# Amikacin_I                   False
# Amoxycillin clavulanate_I    False
# Ampicillin_I                 False
# Cefepime_I                   False
# Ceftazidime_I                False
# Ceftriaxone_I                False
# Imipenem_I                   False
# Levofloxacin_I               False
# Meropenem_I                  False
# Minocycline_I                False
# Piperacillin tazobactam_I    False
# Tigecycline_I                False
# Aztreonam_I                  False
# Aztreonam avibactam_I        False
# Ceftaroline_I                False
# Ceftaroline avibactam_I      False
# Ceftazidime avibactam_I      False
# Colistin_I                   False
# ColistinP80_I                False
# Doripenem_I                  False
# Ertapenem_I                  False
# Ceftolozane tazobactam_I     False
# dtype: bool

# %% [markdown]
# ### Define the percentage of resistant isolates
#
# total = intermediate + susceptible + resistant
# percresistant = (resistant/total)

# %% [markdown]
# ### we need to loop the below pivot_table
# and append it for each antibiotic

# %%
col = 'Amoxycillin clavulanate_I'

df_temp1 = (df_kleb_clean
            .loc[:, ['Country', 'Year', col]]
            .pivot_table(values=col, 
                         index=['Country', 'Year'], 
                         columns=col, 
                         aggfunc='size'
                        )
            .fillna(0)
            .assign(Total=lambda x: x.sum(axis=1))
            .assign(PercResistant=lambda x: 100 * x['Resistant']/x['Total'])
            .assign(Antibiotic=col[:-2])
            .reset_index()
            .drop(columns=['Intermediate', 'Resistant', 'Susceptible', 'Total'])
           )

# %%
df_temp1.head()
# Out:
# Amoxycillin clavulanate_I    Country  Year  PercResistant  \
# 0                          Argentina  2004      36.842105
# 1                          Argentina  2005      50.000000
# 2                          Argentina  2006      39.534884
# 3                          Argentina  2007      37.956204
# 4                          Argentina  2008      39.181287
#
# Amoxycillin clavulanate_I               Antibiotic
# 0                          Amoxycillin clavulanate
# 1                          Amoxycillin clavulanate
# 2                          Amoxycillin clavulanate
# 3                          Amoxycillin clavulanate
# 4                          Amoxycillin clavulanate

# %%
cols_result = ['Country', 'Year', 'PercResistant', 'Antibiotic']
#create empty results dataframe
df_result = pd.DataFrame(columns=cols_result)
#pick the columns that end with "_I"
cols = [x for x in df_kleb_clean.columns if x.endswith('_I')]
#Iterate through the columns
for col in cols:
    df_temp1 = (df_kleb_clean
                .loc[:, ['Country', 'Year', col]]
                .pivot_table(values=col, 
                             index=['Country', 'Year'], 
                             columns=col, 
                             aggfunc='size'
                            )
                .fillna(0)
                .assign(Total=lambda x: x.sum(axis=1))
                .assign(PercResistant=lambda x: 100 * x['Resistant']/x['Total'])
                .assign(Antibiotic=col[:-2])
                .reset_index()
               )
    #Append results of iterations to results dataframe
    df_result = df_result.append(df_temp1[cols_result], ignore_index=True)

# %%
df_result.head()
# Out:
#      Country  Year  PercResistant Antibiotic
# 0  Argentina  2004       0.000000   Amikacin
# 1  Argentina  2005       1.960784   Amikacin
# 2  Argentina  2006       2.325581   Amikacin
# 3  Argentina  2007       2.189781   Amikacin
# 4  Argentina  2008       5.263158   Amikacin

# %%
df_result.to_csv('klebsiella.csv', index=False)
